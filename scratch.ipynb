# %%
import torch.nn as nn
import torch

# %%
layer = nn.Linear(128, 64)
print(layer.weight.shape)  # torch.Size([64, 128]) — out first
# Out:
# torch.Size([64, 128])

# %%
y = torch.tensor([10, 20, 30, 40, 50])  # shape (5,)

indices = torch.tensor([[0, 3, 4],
                        [1, 2, 0]])      # shape (2, 3)

y[indices]
# Out:
# tensor([[10, 40, 50],
#         [20, 30, 10]])
